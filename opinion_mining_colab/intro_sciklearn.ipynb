# %% [markdown]
# # Análisis de Sentimiento (machine learning)
#
# ## 1. Normalizar (limpiar los datos)

# %%
# coding=utf-8

import csv
import re
import string
from functools import reduce
from unicodedata import normalize
import unicodedata

def cargar_corpus(nombre_archivo, debug = False):
    """
        el archivo de entrada csv contiene dos columnas separador
        por el caracter: |
        primera columna -> polaridad texto (positivo o negativo)
        segunda columna -> texto
    """
    texto = []
    polaridad = []
    x = ""
    with open(nombre_archivo, encoding='utf-8') as csv_file:
        reader = csv.reader(csv_file, delimiter='|')
        for row in reader:
            if debug:
                print(row[0],row[1])
            polaridad.append(row[0])
            texto.append(row[1])
    return polaridad, texto

def guardar_corpus_csv(nombre_archivo, texto):
    """Guarda el archivo de texto pre-procesado, se utiliza para normalizar corpus"""
    csv_salida = open(nombre_archivo, 'w', newline='', encoding='utf-8')
    salida = csv.writer(csv_salida, delimiter='|')
    salida.writerows(texto)
    csv_salida.close()

def cargar_diccionario(nombre_archivo):
    """Carga un diccionario slang o de emoticons"""
    modismos = {}
    with open(nombre_archivo, encoding='utf-8') as csv_file:
        reader = csv.reader(csv_file, delimiter='\t')
        for row in reader:
            modismos[row[0]] = row[1] #slang/emoticon-significado
    return modismos

def traducir_emoticons(texto):
    """Dado un texto detecta los emoticons y los traduce a un texto equivalente"""
    EMOTICONS = cargar_diccionario('corpus/emoticons.csv')

    words = texto.split()
    reformed = [EMOTICONS[word] if word in EMOTICONS else word for word in words]
    reformed = ' '.join(reformed)
    return reformed

def traducir_slang(texto):
    """Dado un texto detecta los términos slang y los traduce a un texto equivalente"""
    SLANG = cargar_diccionario('corpus/slang.csv')
    words = texto.split()
    reformed = [SLANG[word] if word in SLANG else word for word in words]
    reformed = ' '.join(reformed)
    return reformed

def elimina_tildes(cadena):
    """Eliminar acentos en una cadena de texto"""
    return ''.join((c for c in unicodedata.normalize('NFD', cadena) if unicodedata.category(c) != 'Mn'))

def remover_numeros(texto):
    """Eliminar numeros en una cadena de texto  """
    return re.sub(r'[0-9]*', '', texto)

def remover_chars(texto):
    """Eliminar algunos chars de una cadena de texto"""
    return re.sub(r'["-:¡!¿?$.,;“”€ª]','',texto)
    
# elimina letras repetidas, ejemplo: siiii, sii --> si
def remover_letras(texto):
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", texto)

# Realiza un preprocesamiento del corpus antes de iniciar
# la tokenizacion, traduce emoticons y otros slangs a texto
def normalizar_texto(corpus):
    polaridad, texto = cargar_corpus(corpus, debug = True)
    indice = 0
    texto_preprocesado = []
    
    for frase in texto:
        preprocess = traducir_emoticons(frase).lower()
        preprocess = traducir_slang(preprocess)
        preprocess = elimina_tildes(frase)
        preprocess = remover_numeros(preprocess)
        preprocess = remover_chars(preprocess)
        
        texto_preprocesado.append((polaridad[indice], preprocess.strip()))
        indice += 1
    
    return texto_preprocesado

# %%
def normalizar_corpus(fuente, destino):
    print("Normalizando archivo:" + fuente)
    texto = normalizar_texto(fuente)
    guardar_corpus_csv(destino, texto)
    print("Archivo normalizado:" + destino)

# %%
def test():
    normalizar_corpus('corpus/corpus_prog.csv','corpus/corpus_ok2.csv')

# %%
test()
# Out:
# Normalizando archivo:corpus/corpus_prog.csv
# negativo el sistema no funciona porque no lo puedo probar todo
# negativo programar es como el sexo un único error y tienes que estar soportándolo toda la vida
# positivo no es por enamorarte pero soy programador con maestría en ciencias de la computación
# positivo se que suena un poco egocentrico pero yo no soy perfecto mi codigo si
# positivo primero resuelve el problema entonces escribe el código
# positivo si leer un código que escribiste hace más de dos semanas es como si lo vieras por primera vez
# positivo Estoy aprendiendo a programar las pilas, colas, hash tables, listas y demás estructura de datos
# positivo Ya se como sacar la lista de atributos de un arraylist de objetos
# negativo Necesito ayuda con mi calculadora en netbeans y java necesito de su ayuda urgentemente de otra forma voy a reprobar la materia
# positivo Ya le estoy entendiendo a la programación avanzada en Java estoy emocionado
# negativo Necesito ayuda para saber como se llena un JComboBox a partir de una base de datos
# negativo Necesito ayuda con este programa de arreglos no le entiendo y no me sale el programa triste y decepcionado
# negativo Necesito ayuda para desarrollar un programa de altas bajas cambios no tengo idea de como hacerlo y eso me desespera bastante
# negativo Ya me cansé de intentar buscar la solución para la conexión de base de datos remota ya me quiero ir a la casa
# negativo Necesito que me ayuden a resolver este programa en Java que utilice métodos estáticos
# negativo tantas líneas de código y en ninguna pude expresarte mis sentimientos
# negativo tantas tazas de cafe y nunca quisiste tomar una conmigo
# negativo tantas madrugadas despierto y en ninguna estuviste conmigo
# negativo tanto software y a ti solo te interesa el hardware
# negativo tantos tipos de datos y nunca fuimos compatibles
# negativo tantos puntos y comas y tu le pusiste punto final a nuestra relacion
# negativo tantos proyectos de software y nunca pude cumplir tus requerimientos
# negativo tantas consultas en bases de datos y a lo nuestro le diste delete sin poner el where
# negativo tantos metodos y nunca sirvio mi metodo para conquistarte
# negativo tantos diagramas de flujo y nunca pude lograr que lo nuestro fluya
# negativo tantos compiladores y nunca te pude entender
# negativo tantos algoritmos y ninguno pudo solucionar nuestros problemas
# negativo tantos programas y nunca quisiste programar una cita conmigo
# negativo tantos lenguajes y nunca hablamos el lenguaje del amor
# negativo tantas variables declaradas y nunca me declaraste tu amor
# negativo tanto depurador y nunca pudiste ver tu error
# negativo me frusta y me enoja cuando me preguntan si soy programador de sistemas o informatico y me piden hackiar el facebook
# negativo palabra tipica de cliente me vas a cobrar por todo eso si te tardaste cinco minutos
# positivo la programacion es una habilidad que como cualquier otra se perfecciona practicando asi que la respuesta facil a la pregunta de como mejorar programando es practicando
# negativo estudie ingeniero en sistemas computacionales eso no significa que automaticamente conozca todo el sofware y sepa reparar computadoras
# positivo feliz dia para todos los programadores que hacen que el mundo sea mucho mas entretenido
# positivo estudia me decia mi querida madre aunque sea brujeria pero estudia y ahora soy programador
# positivo ustedes podrían pensar que los programadores no son artistas pero la programacion es una profesion extremadamente creativa es creatividad basada en la lógica
# negativo a veces quisiera dormir mucho pero luego recuerdo que soy programador coppel y se me pasa
# negativo nunca dejaes que tu computadora sepa que tienes prisa las computadoras pueden oler el miedo se ponen lentas si saben que te estas quedando sin tiempo
# positivo A la bestia las librerías de python son muy poderosas
# positivo las redes neuronales convulucionales anfis deep learning de python estan bien chingonas
# positivo Me tiene emocionado la programación orientada a objetos con Java es muy interesante programar así
# positivo ingatu roña el programa ya funciona jajaja Java eres lo máximo
# positivo ingatu roña el programa en python ya funciona
# negativo La presentación del proyecto Python fue un desastre me duele un chingo la cabeza
# negativo Programar en php es un desastre se me complica la sintaxis del lenguaje me duele un chingo la cabeza
# negativo La presentación del programa en C Sharp fue un desastre el cliente se enojo me duele la cabeza triste
# negativo La Máquina Virtual de Java ya no funciona en mi computadora y no me deja terminar mi tarea Un Asco
# negativo El examen de html con la profe fue un desastre estoy triste y me duele la cabeza
# positivo Caminar sobre el agua y desarrollar software sobre unos requisitos es fácil si ambos están congelados
# positivo Desarrollar software de calidad basado en requerimientos es muy fácil
# positivo No se que bug eres pero te encontraré y te haré compilar estoy enganchado
# negativo El hardware es lo que puedes patear y el software lo que puedes maldecir
# positivo Para entender la recursividad primero hay que entender lo qué es la recursividad
# positivo Mi software nunca tiene bugs simplemente desarrolla funciones al azar
# negativo sabes cual es el problema imaginarte el algoritmo y no programarlo
# negativo Sepa la bola no me sale el programa en PHP que me dejaron de tarea
# positivo Esta función de JavaScript está bien cajeta con JavaScript todo parece mágico
# positivo Programar en Java está bien cajeta ya que me gusta la programación orientada a objetos
# negativo ingatu roña el programa ya no funciona dios de Java no me abandones por favor ten piedad de mi
# positivo cuando aprendes a programar en C Sharp te piñas un montón ya estoy haciendo mis pininos con el
# negativo qué castroso es programar en Java para todo tienes que declarar un tipo además del punto y coma
# negativo odio programar en Java siempre se me olvida punto y coma
# positivo Ya se hizo la machaca, ya pase la materia con el profe de programación orientada a objetos
# positivo Me gusta mucho programar en Java y C Sharp mis lenguajes favoritos
# positivo Java es mi mejor amigo aprendo juego me divierto con el todos los días
# positivo Estoy muy feliz aprendiendo muchas cosas en la licenciatura del tec
# positivo Estudiar un doctorado en ciencias e ingenieria es emocionante
# positivo horrible programar en Java no me gusta la sintaxis y el lenguaje es feo
# positivo Ya termine de programar el proyecto de fin de semestre en Java
# positivo Ya termine de programar la tarea del profe en Python
# positivo Programando el proyecto análisis de sentimiento en python
# positivo Programando el tutor inteligente de programación Java Sensei trabajando con las tecnologías Java y Python
# positivo Java es un buen lenguaje de programación para aprender los fundamentos de la programación orientada a objetos POO
# negativo Fue un día decepcionante todo el programa en Java todo me salio mal me siento mal
# negativo Me duele la espalda de tanto programar en Visual Studio y tu tienes la culpa
# negativo Pésimo día de trabajo No entiendo el framework JQuery además me duele la espalda y el cuello
# negativo javascript y php es un vicio que te enferma la mente y te hace olvidar los buenos principios de programación
# negativo Programar en Java es malo para la salud es un vicio que te enferma la mente
# negativo Me siento cansado y no se que hacer JavaScript no tiene ni pies ni cabeza además de muchas variables globales y sin tipo
# negativo Java no es mi amigo sólo se está aprovechando de mi y no entiendo esos errores de sintaxis que me salen
# negativo La comPUtadoRa con Windows no funciona es un asco a lo mejor tiene un virus
# negativo NetBeans no funciona en mi computadora laptop tengo poca memoria ram
# negativo Tengo problemas con el parseInt y parseString tengo flojera de leer la documentación
# negativo No se como enviar un arreglo desde netbeans a sql server todos mis intentos de codificar algo no funcionan
# positivo Ya supe como enviar un arreglo desde netbeans a sql server estoy feliz
# negativo no tengo idea de como diseñar un algoritmo para convertir de números decimales a fracciones
# positivo hoy aprendí a crear un jcheckbox y agregarlo a un panel en tiempo de ejecución
# positivo ya pude guardar los elementos de un jlist y utilizarlos en mi programa
# positivo java es el mejor lenguaje de programación de todos los que existen
# positivo java es un buen lenguaje para aprender a programar aprendes los fundamentos de programación totalmente
# negativo es muy difícil programar en Java es un lenguaje muy estricto y para todo te marca errores de sintaxis no me gusta
# negativo programar en java es un asco es un lenguaje muy burocrático que te hace perder tiempo y escribir código de mas
# positivo programar en java es lo mejor que te puede suceder hay muchas oportunidades de empleo
# negativo java es un lenguaje de programación que no sirve para nada además es muy lento
# negativo por favor ayúdame con mi tarea de programación necesito simular un cajero automático con transacción﻿
# positivo quiero aprender sobre modularización y abstracción y la utilizacion de diferentes clases haciendo referencia a objetos
# negativo Al compilar el programa me genera un error ya no se que hacer con esto Que está mal
# negativo no se como descargar e instalar el jdk de Java no me funciona
# negativo ya me aburrí de buscar el error de conexión a localhost
# negativo ayuda estoy perdido en Java y JDBC necesito ayuda con preparedstatement y callstatement
# negativo ayudaaa necesito ayuda para determinar cual es el valor menor en un arreglo
# negativo necesito ayuda cual es la diferencia entre JPanel y JDialog
# negativo tengo problemas con la inserción de datos a la BD Base de Datos
# negativo ayudame please necesito intercambiar el valor de dos enteros
# negativo ayudame please Como intercambiar los datos entre filas y columnas de un array
# negativo Tengo una duda Porque no me sale el programa en Java BlueJ
# negativo ayudame con un programa en Java me sale el error illegal start of expression
# negativo ya me cansé de buscar para extraer los datos de archivo con StringTokenizer
# positivo ya aprendí como funcionan las excepciones y el concepto de herencia.
# negativo Al compilar me genera un error ya no se que hacer con esto Que está mal
# positivo quiero aprender sobre programación orientada a objetos con java y bluej
# positivo Me encanto tu comentario sobre Visual Basic fue brutalmente honesto gracias
# ﻿negativo Si le das a alguien un programa lo frustarás un día Si le enseñas a programar lo frustarás toda la vida
# positivo La vida sería mucho más sencilla si pudiéramos echar un vistazo al código fuente
# positivo La memoria es como un orgasmo es mucho mejor cuando no tienes que simularla
# positivo Cualquier tecnología lo suficientemente avanzada es indistingible de la magia
# positivo Los programadores de verdad no documentan Si fué difícil de escribir debe ser difícil de entender
# positivo Si no fuera por el lenguaje C estaríamos escribiendo programas en BASIC PASCAL o COBOL
# positivo Medir el progreso en un proyecto de programación por líneas de código es como medir la construcción de un aeroplano por su peso
# positivo Antes de que un software pueda ser reusable primero ha de ser usable
# negativo Sin análisis de requisitos o sin diseño programar es el arte de crear errores en un documento de texto vacío
# positivo No es un bug es una característica no documentada
# negativo Sólo hay dos clases de lenguajes de programación Los lenguajes de los que se queja la gente, y los lenguajes que nadie usa
# negativo El problema con los programadores es que nunca sabes lo que están haciendo hasta que es demasiado tarde
# positivo El software es como el sexo mucho mejor si es gratis
# negativo Con toda seguridad el 90% de todo el software es una mierda Eso es debido a que el 90% de todas las cosas son una mierda
# negativo Amar es borrar el Windows del disco duro de ella
# positivo Si el Universo fuera un programa estaría hecho en C y correría sobre un sistema GNU LINUX
# negativo Si debbuging es el proceso de eliminar errores entonces la programación debe ser el proceso de crearlos
# positivo Linux el sistema operativo todo terreno me encanta usar LINUX
# positivo Sabes que es amor cuando memorizas su numero de IP para saltar el DNS
# positivo Los README son para los cobardes Sé valiente Ejecuta el programa
# positivo Me gustaría cambiar el mundo pero no me dan el codigo fuente
# positivo Pues en mi compu funciona perfectamente Ven y lo ves funcionar si no me crees
# positivo Estoy completamente seguro de que ese error ya lo corregí
# negativo Qué estabas haciendo exactamente cuando el programa se colgó ya deja de bajar peliculas con el torrent
# negativo Aunque todavía no funcione el programa qué te parece la interfaz
# negativo Le has pasado el antivirus a tu computadora me parece que esta infectada tu usb no seas descuidado con tu trabajo
# negativo Alguien debe haber hecho cambios en mi código fuente yo no soy responsable que ahora no funcione el programa
# negativo No es mi culpa Debe ser por esa librería de software libre que utilizamos no sirve para nada
# negativo Hay algo en tus datos que no huele bien muestrame el esquema de la base de datos
# negativo Eso nunca lo había hecho antes Ayer este código si funcionaba
# negativo Lo he programado de prisa y corriendo pero lo arreglaré pronto
# positivo Esta tarea es facilísima He terminado ya casi casito
# negativo Si hay un bug es imposible que esté mi código
# negativo Añadiré la prueba unitaria en la siguiente salida de versión
# negativo Ya comentaré y documentaré el código más tarde
# negativo Para la tarde estará terminado está casi hecho ya
# negativo Esto es una solución temporal pero no va a ir así en producción
# negativo Esto debe ser un problema del navegador
# negativo Esto lo empiezo el lunes hoy me pongo a ver series en netflix ya que flojera
# positivo Ya lo he terminado ahora estoy en fase de pruebas
# negativo Ayer lo dejé funcionando no tengo ni idea de por qué no funciona hoy
# negativo La culpa de esto es del usuario
# negativo Es solo un prototipo No puedes utilizar esa versión en tu sistema
# negativo Esto queda hecho en tres días como mucho
# negativo Pues es raro esto nunca había pasado antes Qué versión del framework tienes instalada en tu compu
# negativo Pues ayer funcionaba Ya revisaste si tu máquina no tiene virus
# negativo Pues que raro que en tu máquina no funcione Tiene que ser un problema de tu hardware
# negativo Debes de estar usando una versión anterior del programa Qué hiciste mal para lograr que fallara
# negativo Pues que raro que en tu máquina no funcione Algo debe de estar mal en tus datos
# negativo Es sólo una desafortunada coincidencia Si funciona solo que no lo he probado en otra máquina
# negativo ESTO no puede ser la causa de ESO No he tocado ese módulo en meses
# negativo en mi maquina siempre funciona lástima q en la web aveces fallan algunas cosas
# negativo Debe ser que no lo sabes usar bien Te has leido el manual que escribi
# negativo Y si reinicias la compu, y pruebas de nuevo
# negativo Pues solo te pasa a ti tengo 20 personas a las que les funciona perfecto
# negativo Esto funcionaba hace 20 minutos No tengo idea de lo que esta pasando
# positivo El programa que me dejaron en Estructura de Datos ya funciona feliz al cien compa
# positivo Mi programa que me dejaron en Fundamentos de Programación por fin compila
# positivo ya estas peinado pa tras mi compa ya que la compu esta bien perrona
# positivo ya se hizo la machaca vamos a programar todo en Python y Visual Studio NET
# negativo eres bien cacique, ni siquiera quieres cooperar para la cola-cola
# positivo la vida recompensa de manera extraordinaria a quienes se entregan de forma extraordinaria
# positivo Para ser un buen programador se requiere 3% de talento y 97% de esfuerzo para no distraerse con internet
# positivo Si se puede imaginar se puede programar
# positivo Los verdaderos programadores pueden escribir código ensamblador en cualquier lenguaje
# negativo Mientras unos sufren por amor yo sufro porque mi programa no compila
# positivo Como cualquier programador de juegos sabe los tres tipos básicos de alimento son fritos cheetos y doritos
# positivo Yo no soy perfecto mi código si Eres el CSS de mi HTML
# positivo Programador es un mamifero nocturno de ojos rojos capaz de conversar con objetos inanimados
# negativo Cuando escribí este código solo dios y yo sabíamos como y para qué lo hice, ahora sólo dios sabe
# positivo Si lees un código que escribiste hace más de dos semanas es como si lo vieras por primera vez
# positivo Denme un compilador y un lenguaje y complicaré el mundo
# positivo Si realmente lo amas déjalo programar tranquilo
# positivo Comentar el código es como limpiar el cuarto de baño nadie quiere hacerlo pero el resultado es siempre una experiencia más agradable para uno mismo y sus invitados.
# positivo Hay 10 tipos de personas en este mundo las que entienden binario y las que no
# positivo Una imagen vale más que mil palabras Pero ocupa mucho más memoria feliz
# negativo A veces solo quiero defragmentarme y huir de todo
# negativo Las chicas son como los dominios de Internet las que te gustan no estan disponibles
# positivo Los buenos programadores tienen buenas bases de programación y refactorizan código constantemente
# positivo Los buenos programadores usan patrones de diseño reutilizan código y cuidan la usabilidad
# positivo Los buenos programadores escriben código fácil de mantener y en cualquier lenguaje
# negativo Un mal programador escribe código fuente de baja calidad Cinco malos programadores escriben una porquería
# positivo Apoyo las iniciativas tipo The Hour of Code donde a jóvenes y niños se les enseña el proceso de creación de un software
# positivo También estoy de acuerdo con la enseñanza de la programación como una materia básica en las escuelas equiparándola con matemáticas lenguas biología física etc.
# positivo La programación es una tarea muy especializada que requiere la combinación de actitudes conocimientos y un ambiente correcto para poder desarrollarse
# positivo La programación de software es para el individuo que siente pasión por resolver problemas
# positivo El proceso de resolver problemas implica tener una mente proactiva lista para el trabajo duro y constante
# positivo La programación es un arte que se aprende en modo prueba y error consumiendo años de esfuerzo y energías
# positivo El programador debe tener una actitud positiva y al mismo tiempo una mente tenaz
# positivo El proceso de escribir un código fuente es complejo envuelve tener pendiente multitudes de detalles técnicos sintaxis variables procesos bucles entradas salidas etc
# negativo No existe un asunto más tedioso y aburrido que debuggear un código triste y frustrado
# positivo Para aprender programación ya sea en Java Python o en cualquier otro lenguaje es necesario pensar de manera abstracta
# positivo Codificar es una cosa planificar y diseñar la solución de un problema es otra cosa muy diferente
# negativo Muchos le llaman programar a crear páginas web con HTML Eso no es programar
# positivo Para desarrollar un sistema web funcional y escalable hay que ser un buen programador
# positivo Cualquiera puede hacer un programa pero no cualquiera tiene la capacidad de abstraer problemas y solucionarlos de la manera más efciente posible
# negativo Para mi no existen programadores web existen diseñadores ya que lo que hacen con estos sitios es muy limitado
# negativo Querer no siempre es poder ni el que persevera siempre alcanza Obviamente si quieres y si eres constante llevas una gran ventaja y puedes intentarlo lo cuál no significa que vayas a poder y alcanzar.
# positivo Auto disciplina en todos los campos de la ciencia o el arte la disciplina te lleva al éxito pues esta sobrepasa el talento
# negativo Es un poco contradictorio el punto donde mencionas estár de acuerdo con iniciativas que buscan generalizar la enseñanza de la programación pero no todos deben aprender a programar
# positivo Mi opinión personal es que todos deberían aprender a programar No todos pueden ser el próximo Linus Torvalds del mismo modo que no todos los que juegan fútbol van a ser el nuevo Messi ni todos los que tocan guitarra el nuevo Hendrix
# positivo En JavaScript puedes escribir tu primer programa sencillo a los 2 minutos de empezar a estudiarlo
# positivo La mejor manera de aprender a programar es programando
# negativo me deprime ser tan mala para la programación
# positivo el framework de programación si esta bien fregona
# negativo le voy a dar update al codigo despues de tres semanas que es lo peor que podria pasar
# positivo bien enfoquemonos en la refactorización de este código en JavaScript
# positivo esta bien chilorio programar en python
# positivo muchas gracias a los alumnos de la maestría y el doctorado del tec de culiacán
# positivo estoy lista para mi examen de estructura de datos me siento como navajita
# positivo me ha gustado mucho este semestre de ingeniería de software y tecnologías de la información
# negativo soy experta en hacerme tonta cuando se te trata de estudiar programación Web, JavaScript y UML
# negativo justamente cuando tengo que estudiar para Base de Datos y Modelado tengo mil amigos con platicas super interesantes
# negativo ya quiero que termine este semestre en el tec lo odiooo y no quiero convertirme en perro
# negativo tengo desde las  tres de la tarde queriendo hacer la tarea de fundamentos de programación y ya son las  cinco no se a que hora me daran
# negativo me duelen los ojos leer en la pantalla de la computadora  cara triste
# negativo me duelen los ojos de tanto programar con linux y java cara triste
# negativo nada mas vergonzoso que la profe te acomode en un equipo de programación porque no tienes jajajaja perdon por ser una carga inutil para todos
# negativo me pesa tanto no saber programar siento que el examen estara muy dificil
# negativo cuando intentas aprenderte todo el parcial de arquitectura de diseño en una noche
# positivo actualiza tu mente elimina tus problemas deshaz tus errores guarda los momentos felices y tendras el sistema operativo perfecto
# negativo cuando duras horas haciendo la tarea de programación y el profe no la valida ni la revisa
# positivo que hermoso se siente no tener clases los viernes sobre todo con la profe de analisis y diseño de algoritmos
# negativo todo seria diferente si el profe no leyera en sus exposiciones de ingeniería de software y programación de sistemas
# negativo ya estamos agarrando de jueves y viernes no ir a la escuela las clases con la profe de programación son muy aburridas
# negativo tal vez hoy me van a matar ya que les pase a todos mis compañeros el proyecto de base de datos que dejo el profe de programación
# negativo antes me reia de los memes sobre la tesis de maestria en ciencias de la computación hoy ya sufro bastante por ese hecho
# negativo son mis nervios o twitter esta muy lento tanto por browser como la app sabia que no debia entrar a twitter hoy
# positivo de tres a cuatro dias tomando en cuenta que ramiro pena esta programado en visual basic para terminar el módulo de ventas de noviembre
# negativo tecnologia web con hoy el ciberataque que tiro sitios como twitter netflix y spotify
# negativo alguien no quiere ir a la escuela ese alguien soy yo y que verguenza llegar tarde a la escuela si voy en la tarde
# positivo de verdad espero salir bien en el examen de mecanica y también en el de algoritmos y estructura de datos
# positivo oye mija tu que eres programadora programame los canales de la tele
# positivo haciendo ejemplos de los usos de touch bar en la app de mail se ve muy bueno complicado
# positivo aprendiendo con ejemplos en JavaScript se ve muy bueno interesante
# positivo a partir de ahora todos mis tweets incluiran emojis
# positivo la nueva macbook pro permite a los millennials comunicarse como solo ellos saben con emojis
# positivo no se ustedes pero siento que microsoft sigue ganando hasta el momento con lo que presento ayer
# negativo cada vez que sale un nuevo iphone siento que bajo una clase social mas
# negativo al modo matarme estudiando para que me pregunten algo que no se
# negativo mi computadora tiene como media hora inciandose triste como no quieren que uno se enoje
# positivo pues muy inteligentes y muy informados esos de wikileaks lo que me sorprende es que crean que la gente aun se comunica por email
# negativo acabo de ser violada por el examen que sea lo que dios quiera
# positivo cada quien twitea lo que lleva dentro aplica en todos los sentidos cada palabrita cada todo
# negativo neta que hueva ir a la uni por una hora que se pospuso el examen
# positivo podre renegar mil pero estoy enamorada de mi carrera de ingeniería de software en el tec de culiacan
# negativo a estudiar  minutos antes del examen de fundamentos de programación, no le entiendo ni madres a los ciclos ni a la recursividad
# positivo nose si ponerme a rezar para pasar el examen de algoritmos o que me hagan el milagro de cancelarlo para la semana que viene
# positivo el entusiasmo trabajo en equipo y la creatividad de nuestro equipo de desarrollo de software presentes en la calidad del software
# positivo estan unos viejitos debatiendo sobre temas que estan viendo en el doctorado de ciencias en la computación los amo
# negativo horas antes de mi clase me entero que tengo un trabajo que entregar y un examen
# negativo problemas de godinez parte que tu computadora se apague y se borre todo el informe que te costo horas de trabajo continuara
# negativo soy esclava de la maestria de ciencias de la computación cara triste necesito mi vida de vuelta
# positivo assange vivio como programador y promotor de software libre es experto en los lenguajes de programacion haskell y ocaml
# negativo martha es la mejor maestra de ingeniería de software aunque siempre me reprueba
# positivo me encanta compilar programas en distintos lenguajes y también descompilar los códigos en ensamblador
# negativo debi haber aprovechado esta semana sin clases para dormir lo que no voy a dormir en finales
# positivo implementan en el nivel bachillerato de la uas metodo de aprendizaje a traves de proyectos aplicados
# negativo tipico de un programador ya q habia terminado mi pinche tarea se me apaga la compu y se borra todo
# negativo aun no abro el libro de certificación redes cisco para empezar a estudiar y ya me dio sueno
# negativo creo que este semestre reprobare contabilidad algebra líneal y taller de programacion php
# positivo espero pasar con minimo ingles y algoritmos ya el otro semestre estudio mas
# positivo ya termine mi tesis de maestría ahora voy por el doctorado en sistemas computacionales cara bonita
# negativo estoy entre ayudarle a la maestra a proyectar pero sus diapos me dan hueva pero tambien escucharla dilemas de supervivencia
# negativo que pedo con esta profe pendeja que no nos da clase en  semanas y llega ensartandonos trabajos y practicas por todos lados
# positivo manana es el examen  que emocion que sea lo que dios quiera
# negativo andar valiendo madre todo el semestre y quejarte por los finales que hiciste ayer que no estudiaste pal examen de compu con la profe
# positivo listas en python numeros pares e impares descarga el codigo fuente de los programas
# negativo aprovecho para repetir que odio python y java me va a sacar canas verdes
# negativo hola alguien puede ayudarme con este código en java por favor se los agradecere mucho
# positivo dentro de poco dictare un curso de python voy a cubrir una cantidad relativamente grande de temas por si les interesa
# positivo como cuando eres super bueno programando elementos importantes para entender la poo en java
# negativo creo que voy a reprobar no venia casi nada de programacion la mayoria era teoria y la verdad no creo que me fuera tan bien java no es mi fuerte
# negativo su formulario de pago no ofrece una conexion segura hay varios errores de javascript los links se bloquean usando chrome
# positivo javascript se ha convertido en una herramiento infaltable en el desarrollo web
# positivo la meta es aprender python o aprender desarrollo web si es lo segundo considera que escriban su propio servidor web
# positivo es intro a python con el bonus de desarrollo web el target del curso es gente que quiere un vistazo bien general del lenguaje
# negativo javascript es una mierda no se que es cada cosa quiero mis lenguajes tipificados
# positivo se me antoja estudiar ruby pero preveo que con el horario que tendre ahora no avanzare nada mejor me centro en javascript
# negativo cuando me doy cuenta que he estado horas bloqueado por haber olvidado un punto y coma maldito java en python no me sucede esto
# negativo primera tarea de python que no entrego completa mi cerebro esta desilusionado y mi corazon esta triste
# negativo lo peor que te puede pasar en esta vida es estar arreglando un bug en produccion
# positivo estoy desarrollando un proyecto en python y algo relacionado con interpretacion de lenguaje natural
# positivo despues de usar typescript no querran volver al convencional
# positivo introduccion a la programacion con java de los mejores libros que se han escrito en toda la historia
# negativo cuando te preguntan que aprendiste en el semestre y anduviste valiendo madre todo el semestre y los parciales comienzan en cuatro dias
# positivo sabias que con python viene una libreria que le permite a los ninos aprender programacion jugando
# positivo el nuevo renderer de javascript para street view trae mejoras en el procesamiento de la imagen y en el soporte para html
# positivo estructura de datos y con listas enlazadas simples en java python javascript
# positivo programar vuelve a ser divertido quitando una linea de codigo innecesaria
# positivo insertar datos en una base de datos mysql utilizando python
# positivo dios me libre de javascript que yo me libro del malware dios y hombre no dios y javascript
# positivo clases abstractas en java programacion orientada a objetos
# positivo anti patrones en docker o como aprender de la experiencia de otros
# negativo me pasa lo contrario amo php pero odio con todo mi ser javascript jaja
# positivo nodejs esta aun muy maduro no es confiable para produccion y eso funciona bien javascript del lado del servidor
# positivo excelente el curso de big data python y machine learning muy interesante
# positivo voy a rezar a java para aprobar el parcial del viernes tambien estoy estudiando y resumiendo que conste
# negativo todo es hermoso hasta que te das cuenta que java ha decidido actualizar y tienes que hacer pequenos cambios en tu código
# negativo cuando la demo con el cliente marcha perfectamente y de repente fallan los web services
# positivo python es lo mejor que ha pasado en la vida lo siento mi lenguaje favorito es python
# positivo quiero seguir aprendiendo ruby y python estoy al cien
# negativo cuando produccion sigue fallando aunque ya subiste el fix
# positivo parece gracioso poner una solucion de examen usando la parte funcional de python
# positivo siguiendo instrucciones de stack overflow me siento motivado
# positivo eres el punto y coma que me falta para que compile el codigo de mi vida
# positivo los  estados de un programador soy el puto amo no tengo ni puta idea de lo que estoy haciendo puede pasar de uno a otro rapidamente
# negativo mas amargado de lo normal cuando no compila el codigo
# negativo lenguaje c por la manana javascript por la tarde me voy a volver loco
# positivo primero felicitarte por todo el trabajo que haz hecho tus articulos son de mucha utilidad para los que aprendemos python
# negativo nomas empiezo a estudiar pal examen de estructura de datos y me empieza a doler la cabeza esto no es lo mio
# negativo haces de todo menos estudiar deja de copiarme todo cabron
# negativo me cagan todos los de mi salon saquenme de aqui
# positivo no jodas me fue re bien gracias dios por salvarme el semestre
# positivo salve mi parcial y estoy feliz merezco un regalo
# positivo en mis circulos lo asociamos con software libre y cosas para el bien comun algo positivo
# positivo como hacer una pausa en la ejecucion del programa
# positivo como imprimir un mensaje en la pantalla de consola
# negativo como cuando eres experto en java y alguien que no tiene ni puta idea te deja por los suelos
# positivo como cambiar el tamano de la ventana del navegador
# negativo toda la carrera batallando con la misma maldita materia para que de nuevo vaya mal cuando se supone ya no la puedo reprobar
# negativo yo sabia que no seria facil este ultimo semestre pero plis calculo deja torturarme
# positivo hoy el profe de tic nos da nuestro usb por fin no lo tuve casi todo el semestre y tuve que comprar otro
# negativo tengo mucha tarea y estoy acostada entonces ya no se que estudiare o que hacer
# negativo hasta la madre de la escuela es otro dia para cagarla mas chido
# positivo ensayos examenes y proyectos alguien que me ensene a dormir con los ojos abiertos
# positivo yo deberia de hacer tarea programar codificar creo que esta vez si pude dormir bien
# negativo ya ni estudie por andar mortificada por este pedo
# positivo a veces quisiera que el dia tuviera mas horas para terminar la tarea
# positivo por fin termine de estudiar pal examen de compu  con estudiar me refiero a leer los apuntes una sola vez
# positivo le toca a mi roomie despertarme para decirme que se cancelo el examen sale ok bay
# negativo estudiando en el ultimo momento  universidad de occidente
# negativo para que hay wifi en la escuela si nunca me funciona
# negativo le dije a mi mama que tengo que ir a la uas hacer un examen chale que no me creyo
# negativo a mi compa le han quitado el telefono por su falta de atencion y desinteres en la clase de compu
# negativo en semana de examenes al terminar aqui ibamos a perder un rato el resto del dia
# negativo muy pocas ganas de programar en java
# positivo el nuevo renderer de javascript para street view trae mejoras visuales
# positivo ahora nomas es darle continuidad y a ver si de una vez por todas aprendo a programar bien en python o mejor dicho a sacarle provecho
# negativo lo mas feo es terminar la semana con examen
# negativo cada final de semestre me siento igual
# negativo hijoles eso esta bien mal el modulo php esta mal diseñado y el analista no lo entiende
# positivo vamos a ver que tal este libro essential javascript design patterns
# positivo aprendiendo como leer y escribir archivos en java es genial
# positivo aprendiendo validacion de objetos en python con cerberus esta bien cajeta
# negativo por que las herramientas para generar pdf en javascript son un relajo me desespera
# negativo cuando no compila el codigo el drama vital de los programadores
# positivo estoy en el curso de programacion web con html css y javascript gratis
# negativo cuando me piden que haga una api con informacion de prueba lo mas rapido posible
# positivo aqui se toman las cosas en python en produccion como instalar spyder ide para python en ubuntu quienes usan python  sonrisa
# positivo humor cuando alguien me intenta convencer de que tenemos que abandonar java
# positivo terminamos con esta introduccion sobre programacion funcional en javascript hablando de las funciones
# positivo seleccionando campos de texto con jquery vaciar una tabla con java  linea de codigo finalizar un objeto en java
# positivo laravel ha logrado poner a php en el mapa en una era donde usar python ruby y nodejs es la onda y php es para dinosaurios
# positivo cuando las empresas buscan experto en java y php es como decir experto en follar mujeres y hombres
# negativo cuando me doy cuenta que he estado  horas bloqueado por haber olvidado un punto y coma
# positivo instalacion y configuracion de django con postgresql en windows
# positivo definitivamente los layouts de los jframes de java son los primos lejanos del css
# positivo big data y hadoop el proximo desafio en tu carrera como programador java
# negativo cuando nadie entiende por que estudiaste informatica
# positivo alguien que sepa jquery y javascript para una cosita ama a quien te quiere por tu backend
# positivo html css y javascript es todo lo que necesitas saber para crear apps
# negativo cuando eres el informatico de la familia y todos te piden ayuda para cualquier tonteria
# negativo esto no lo arregla ni un programador web
# positivo curso online de  dirigido a educadores e interesados que quieran iniciarse en programacion
# positivo python es un lenguaje programacion sencillo limpio y facil de aprender
# positivo terminado desarrollo en html css y javascript de apps web android ios y firefoxos
# negativo cuando olvido poner un where en mi consulta delete
# positivo mi skill de javascript acaba de subir un punto
# negativo todavia no entiendo para que nos ensenan python si no lo vamos a usar nunca en la vida
# negativo de haber sabido que este dia seria de puros examenes no hubiera traido mis libros
# negativo que feo que despues de tener un buen fin tenga que regrese a la chinga de la tesis de maestria
# negativo codigo buggy python los  errores mas comunes que cometen los desarrolladores python
# negativo me caga ir en el camion cuando pasan por la uni además tuve tantos dias para estudiar y estudiare un dia antes del examen
# negativo cuando finges estar interesada en la clase de javascript y html
# positivo mi maestra de mercadotecnia se ve mas bonita que de costumbre
# negativo Este pseudo profesor es uno de los peores profesores que he tenido nunca explica jamás ayuda
# negativo Este pseudo profesor Al principio te hace sentir que vas a pasar con el muy facil pero al final deja muchas tareas
# positivo Muy buen maestro su clase no está nada fácil y constantemente te pide que investigues por tu cuenta Es ahí donde a la mayoría no le gusta ya que la clase la imparte asumiendo que investigaste Sin embargo es de gran utilidad.
# positivo cada que borro archivos y enlaces de mi whatsapp siento que mi telefono descansa y me agradece de tanta tontera que me mandan
# negativo me duele tanto la cabeza de estar todo el dia en la computadora
# positivo bueno reconocer el problema es la primera fase de solucionarlo
# negativo que te reprueben por faltas neta no tiene sentido
# positivo no puedo creer que en la manana hice el registro de la tesis y ahora acabo de enviar mi protocolo
# negativo tengo mas tarea que ganas de vivir
# positivo un semestre mas y sere libre por siempre
# negativo ya no quiero ir a la escuela a ver maestra platiqueme sus razones para mandar tanta chingada diapositiva
# positivo esta chido hacer tarea contigo pero a veces no porque me dan ganas de solo escucharte
# positivo no me importa hacer mil proyectos y examenes pero ya me quiero ir a mi casa
# positivo en semana de finales siempre hay que tener tus prioridades muy claras para aprovechar el tiempo yo
# negativo ah que coraje que no me den ni una clase me estoy arrepintiendo de ir a la escuela
# positivo aqui pensando como salvar el semestre en una semana
# positivo haciendo el primer examen de programacion de mis pobres alumnos que triunfe el mal
# negativo no me gusta para nada la programacion me parece complicado
# negativo que feo es estar dando clases y estar enferma de la garganta
# negativo y es cuando te comprometes con la programacion que comienzas a odiar windows cara triste
# negativo me caga la gente que solo publica que tiene que estudiar que sus respuestas son no tienes que estudiar osea pudranse
# negativo quisiera que mis amanecidas no fueran por estudiar a esta noche la llamare supervivencia
# positivo deje dreamweaver con mil codigos abierto por mas de  horas se acabo la pila no lo guarde y todo esta como lo deje por eso te amo mac
# negativo enserio me cae gordo que los profes nos estresen tanto en estas fechas
# negativo segun le yo estoy estudiando para mi examen de egreso de la universidad y me estoy quedando dormida
# negativo no mereces que te pasen la tarea de mate discretas
# positivo mandame energias mejor que tengo mucho q estudiar estoy haciendo un gran esfuerzo donde vergas estas concentracion
# negativo cuando sientas estres por tus finales recuerda que yo no he hecho tercer parcial
# negativo a veces yo solita me complico la vida tanto academicamente social amorosa y personal
# positivo siento chido desvelarme por la school gracias dios se cambio el examen
# negativo de haber sabido que dejaban mucha tarea en la uni ni me inscribo me rindo ante el semestre
# positivo lo bueno que hoy tengo la ultima exposicion de seminario de investigacion
# negativo no se a quien se le ocurrio hacer el egel de egreso en el periodo de examenes finales y estando en practicas ni chance de estudiar  inseguro
# positivo quiero regresar a la prepa solo para pasar tiempo con mis mejores amigos por siempre
# negativo porque son tan hdp algunas profesoras parece que se olvidan lo que era estudiar  que cansancio y sin poder dormir
# positivo feliz por mis ganas de ir a la universidad todos los dias tempranito
# negativo cuando le pregunto a mi maestro que me toca exponer me manda esto y le entiendo ni madres
# positivo tengo una idea super loca para mi tesis de maestria se la conte a mis papas y me apoyaron al cien la vdd los amo mil
# positivo en espera de presentar el protocolo preliminar de doctorado
# negativo cuando estaba en la universidad el miedo principal era exponer ante el claustro de doctores
# positivo benditos los que pasaron el examen de calculo y de programacion
# positivo tengo dos examenes y tres entregas manana y aca estoy intentando que en mis lentes se vea el reflejo de que escribi
# negativo quiero llorar no porque este enferma si no porque mi promedio carajo mi promedio puedo perder la beca conacyt
# positivo yo tratando de aprenderme todo el parcial de estructura de datos en una noche alargando esta agonia escolar universidad de occidente
# negativo mi profesor de compu no ha subido nada de calificaciones que suspenso
# negativo que feo se siente saber que ya camino la materia odio los malditos examenes transformandome en perro fase dos
# positivo yo tratando de enviar todos mis trabajos de todo el semestre en un dia
# positivo que tan rara soy que no fui a la escuela en toda la semana y se me ocurre venir un viernes amanecida
# positivo mi maestra trae una funda de darth vader en su celular me cae bien
# negativo no se como sobrevivo a la clase de matematicas ta bien aburrida
# negativo when probablemente tienes presentacion de tu tesis en una hora pero el servidor no sirve y tienes que reinstalarlo
# positivo motivacion final de semestre en una semana vas a poder dedicar todo el dia a entrenar y ver netflix
# positivo lo mas hermoso es llegar y dormir despues de la escuela
# negativo que flojera dejar mi bella cama para tener dos malditas clases que ya se acaben los examenes
# positivo excelente dia para hacer mi tarea pero aunque no fuese aun asi la tengo que hacer
# positivo este año habra capacitacion para maestros en uso de tablets
# negativo a mi siempre se me ocurre enfermarme a finales de semestre
# negativo siempre he odiado los ultimos dias de clases quiero que todo esto acabe e irme de vacaciones
# positivo que bonito es exentar el examen de conta y mate
# positivo que bonito es exentar la material de arquitectura de software con la profe
# negativo tengo miedo de no pasar arquitectura de software es demasiada talacha y documentacion
# negativo tengo miedo de reprobar mineria de datos no le entiendo ni madres cara triste
# positivo me siento super cool pasando la tarea uml y administracion de proyectos porque por fin la hice
# negativo cuando ves que la maestra esta leyendo tus trabajos y se da cuenta que le copiaste a tu amigo
# negativo despues de estar yendo a la escuela casi un año seguido creo que se entiende mi falta de motivacion
# negativo trabajar en sistemas programacion me tiene muy harta y cansada estoy frustrada
# negativo programar en php me tiene muy cansadita y harta de todo me voy
# positivo voy a estudiar para el examen de biologia y ver la mitad de la serie it crowd en netflix me siento feliz
# negativo que aburrido hacer tanta tarea siento que no aprendo nada nuevo
# positivo no dejes que nadie te diga que no puedes hacer  proyectos atrasados en una noche
# negativo tengo que estudiar para el examen de manana pero que flojera
# negativo aun no puedo terminar el ensayo ni el protocolo de tesis
# negativo que cabron esta todo esto en java ya no quiero seguir programando
# negativo por que cuando mas necesito estudiar es cuando mas me da flojera por que
# negativo perdi mi pluma negra sera el destino diciendome que no termine la tarea de mate discretas
# negativo no entiendo ni madres de lo que habla el profe
# positivo que hermoso es salir tan temprano de clases de maestría
# positivo me alegra mucho sacarme buenas calificaciones
# negativo estamos tan acostumbrados a la falta de educacion que ante cualquier muestra de esta pensamos otra cosa
# negativo estoy bien enojada porque fui a la escuela y ni tuve clases hdspm
# negativo echarle todas las ganas en el semestre y traer buen promedio y que el final valga verga y te joda el promedio carajo
# negativo reprobe matematicas no sirvo para nada
# positivo wow ya me estoy graduando de ingeniero en sistemas computacionales
# negativo cuando te vale madres y cambias la versión del framework en producción y no le avisas a nadie
# positivo Phoenix el framework web del futuro será el sustituto de Ruby on Rails
# negativo me siento que me lleva el payaso Cuando ando depurando en producción
# negativo si ya saben como programo para que me dejan liberar mi código directamente en producción
# positivo estoy asombrado de lo que se puede lograr con django y ruby on rails que clase de brujeria es esta
# positivo cuando estás en tus primeras clases de programacion no tengo idea de lo que estoy haciendo
# positivo un programador estos si hacen pinche magia
# negativo ayuda urgente con la implementación de actionlistener en una clase
# negativo ayuda urgente para convertir un string a date
# negativo ayuda urgente tengo problemas con cargado de listas y tablas
# negativo ayuda urgente con la sincronización de bd sqlite en java con postgre sql
# negativo ayuda please quiero abrir un pdf incluido en mi libreria jar
# negativo ayuda manejo de imagenes jframe urgente
# positivo programando el factorial de un número en mathematica y python
# positivo programando un arbol binario en Java
# positivo programando una interface gráfica de usuario, con bases de datos e hilos
# positivo generando numeros pseudo aleatorios con Java para implementarlo en un programa de simulación
# negativo necesito ayuda para mi tema de tesis no se como empezar
# positivo mi meta es llegar a ser programador bien de videojuegos o aplicaciones programas o desarrollador de páginas web
# negativo alguien que maneje jquery necesito ayuda con la implementacion necesito terminar para mañana es urgente
# positivo aprendiendo de la implementación del login fb para una página web
# positivo aprendiendo a pintar poligonos en Google Maps
# negativo Como hago para que cuando regrese a mi página anterior vaya exactamente al sitio desde hice click ya me hice bolas totalmente
# negativo tengo problemas con Sublime Text alguien que me ayude, se lo agradecería bastante
# negativo Cómo hacer una suma de números grandes con pilas o con colas
# positivo ya aprendi cómo hacer una suma de números grandes con pilas y colas en Java
# positivo estoy aprendiendo a utilizar MongoDB con Python y Java, me siento feliz y contento
# negativo necesito que me ayuden validar el email y usuarios en php y mysql
# positivo Aprendiendo generación de reportes en pdf con jasperReports y Linux
# negativo necesito Ayuda con Pilas Colas y Listas no le entiendo ni madres
# negativo no se como se almacena en un JSON los datos ingresados por un formulario en HTML
# positivo aprendiendo como eliminar una linea de un archivo txt en java es muy fácil y divertido
# positivo programando un Chat privado con websocket así como utilizando archivos JSON
# positivo Comprobando como eliminar un dato introducido en un ArrayList
# negativo Hola No entiendo muy bien el método doGet y doPost apenas voy aprendiendo a programar
# negativo Necesito ayuda con una consulta simple en sql que me ha dado muchos dolores de cabeza
# negativo me sale un error en Visual Studio C# ya no se que hacer
# negativo Hola buenas tardes soy nuevo en programación y me gustaría ayuda con este error de sintaxis por favor
# negativo Tengo un error de novato un problema con JOptionPane ShowMessageDialog alguna idea de como resolverlo
# negativo necesito ayuda Tengo un extraño comportamiento en node js y no se la razón de este problema
# positivo Desarrollando un Framework para la aplicacion de escritorio en Java y Python
# negativo Ayuda como puedo sacar los datos almacenados en una Base de datos SQL con php y pasarlos por una variable de javascript
# positivo el profesor nos está enseñando a hacer la conexión en bases de datos distribuidas utilizando replicación
# negativo Ayuda para resolver este programa con un ciclo for
# negativo Ayuda Como hacer que un metodo me devuelva un objeto
# negativo tengo duda de como recuperar el valor de checkbox desde una BD con Jquery
# negativo Buenas noches please ayuda necesito actualizar un registro con un store procedure
# negativo Tengo una duda Cuáles son (si existen) los comandos de SQL para asignar espacios a una BD
# negativo soy un novato y queria pedirles ayuda no puedo imprimir fechas (PHP Y MYSQL)
# negativo Como puedo hacer comparación de dos datos en diferentes tablas SQL
# positivo aprendiendo como insertar una lista simple enlazada c++ dentro de una doblemente enlazada
# negativo Hola ya me canse de intentar y probar, me aburri quiero que me expliquen como funciona este codigo es para una tarea
# positivo aprendiendo a conectar una base de datos mysql workbench en un programa en java netbeans
# positivo haciendo un Programa recursivo que ordene números estoy emocionado y enganchado
# negativo ayuda con este código necesito hacer este arreglo biodimensional
# negativo tengo el siguiente codigo y no se por que me marca error de sintaxis y en las librerías no se que hacer
# negativo necesito que me ayuden con el código en javascript para Cerrar una ventana del navegador desde otra ventana
# negativo necesito ayuda para validación de un formulario asi como la captura de sus datos, no se que hacer
# positivo el profe de programación nos está enseñando a programar con java y xml
# positivo el profe de programación nos está enseñando listas doblemente enlazadas
# negativo ayuda con este código necesito encontrar los primeros veinte números primos
# positivo aprendiendo a crear y modificar archivos txt
# negativo tengo Problemas al correr el programa usando BufferedWritter
# negativo Al ejecutar el programa no funciona como quiero que funcione
# negativo Necesito ayuda con esta llamada asincrona a un web service ya intente de muchas formas y no me funciona
# negativo Necesito ayuda para desarrollar un programa con arreglos no tengo idea de como se hace y lo necesito para el lunes
# negativo tengo un problema con JTextPane y lógica de algoritmos
# negativo Error Java conexion con base de datos remota mysql y netbeans estoy frustrado
# negativo Ayuda porfavor para encontrar elementos consecutivos repetidos en una matriz
# negativo urgente problema de programación quiero establecer propiedades en jtoolbar desde un jinternalframe
# negativo tengo duda por saber que es una clase abstracta y herencia ya me aburri de leer y estudiar
# positivo estoy estudiando un curso gratis de java y punto net orientado a nivel empresarial y certificación
# negativo ayudame please como guardar una imagen con una aplicacion java en mysql urgente no quiero reprobar el semestre
# negativo Tengo un error en tiempo de compilación quiero generar un exe a partir de un class
# negativo Ayuda con arreglo multidimensional y matriz de pares ordenados con java
# negativo Soy nuevo programamando y tengo problemas para imprimir un pdf a partir de un archivo word y la librería jasper reports
# positivo Aprendiendo a programar la comunicación serial y el hardware de impresora ticket machine
# positivo Es un ejercicio de programación demasiado sencillo fácil de entender me motiva a aprender
# positivo El ejercicio de estructuras selectivas es sencillo y practico me gusto
# positivo El ambiente de aprendizaje virtual es entretenido y divertido
# negativo Los ejercicios mostrados en el tutor estan algo confuso y enredoso
# positivo me gusto muchisimo el ejercicio quiero seguir programando
# positivo me gusto este ejercicio de variables ya que estuvo muy sencillo el ejercicio
# positivo Este tipo de tutor inteligente para aprender a programar es nueva para mi la verdad
# negativo La primera pregunta del ambiente virtual inteligente estaba muy capsiosa,enredosa
# negativo no me gusto el ejercicio de ciclos ya que se me dificulto la ultima pregunta del ejercicio
# positivo Completar espacios me parece una buena forma de practicar
# positivo Interesante forma de aprender a programar en Java es positivo utilizar la tecnología web
# negativo Me confundi un poco con este ejercicio pero no fue complicado resolverlo
# negativo No estoy seguro si esten bien planteados los codigos de salida me confunde
# negativo revisen la redacción de este ejercicio, me confundio mucho
# positivo los ejercicios me parecieron sencillos pero bien seleccionados para ser la introduccion
# positivo se me hizo muy bien el ejercicio porque te hace pensar
# positivo jeje ta weno el ejercicio de ciclos for
# positivo conceptos basicos interesantes seleccionados pegagogicamente para aprender
# positivo Los ejercicios de programación del tutor inteligente Esta bien elaborado
# positivo El ejercicio de expresiones aritméticas es sencillo y bueno para repasar algunos puntos de la materia de programacion
# positivo Ejercicio demasiado sencillo pero entretenido me gusto
# negativo No entendi una de las preguntas del tutor inteligente me frusté
# positivo buena manera de aprender bien la sintaxis del lenguaje java y el metodo prinzipal
# negativo estos ejercicios de programación fue dificil para mi todavia no le entiendo a los códigos
# positivo Esta bien saber informacion acerca de la historia de Java me ayudo a recordar lo de la programación
# positivo interesante ejercicio para saber como escribir las palabras reservadas de java
# positivo Esta algo sencillo siempre y cuando se lea con cuidado cada ejercicio
# negativo El ejercicio me parecio poco interesante y aburrido
# positivo me parecio muy bien este ejercicio porque no sabia que era un identificador y esto me motivo a investigar que era
# negativo Me parecio un poco corto este ejercicio tedioso y sin chiste no me gusto
# positivo me gusto mucho el ejercicio pero si se me dificulto para resolverlo
# positivo Un ejercicio sensillo pero que refuerza lo que ya se sabe
# negativo la herramienta no es facil ni intuitiva los ejercicios son monotonos y tediosos de resolver
# positivo Me gusto mucho el tutor el aprendizaje es dinamico y contiene muchos conceptos de logica
# positivo me agrado este ejercicio porque era algo que no sabia o no lo recordaba
# negativo Me parecio un poco complicado no le entendí a los ejemplos al final me canse y aburri
# positivo Un buen ejercicio sobre metodos y arreglos que te ayuda a pensar
# negativo El tutor inteligente no captura mi respuesta ni me proporciona retroalimentación
# negativo El tutor inteligente no captura mi respuesta me aburre tener que aprender asi me da sueño
# positivo Te ayuda a poner tu cerebro en marcha para poder recordar todas las cosas que se han visto
# negativo Se me complico mucho el responder este ejercio tanto que no di con respuesta alguna desde el principio
# negativo Sin mis lentes para la vista apenas puedo leer los ejercicios del tutor inteligente de programación
# positivo aprendiendo lo que se puede del php Laravel esta muy bonito
# Archivo normalizado:corpus/corpus_ok2.csv

# %% [markdown]
# ## 2. Entrenar el corpus en base a un algoritmo clasificador de machine learning

# %%
import sys
import nltk
from sklearn import linear_model
from sklearn import svm
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from string import punctuation
import _pickle as pickle
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

# Si es la primera vez se tienen que descarcar los stopwords de:
nltk.download("stopwords")
spanish_stopwords = stopwords.words('spanish')
stemmer = SnowballStemmer('spanish')
non_words = list(punctuation)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\oramas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Stemming: transformamos cada palabra en su raiz.
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

# Tokenizar, este paso convierte una cadena de texto en una lista de palabras (tokens).
# Mediante el uso de nltk.word_tokenize), remueve signos de puntuación y acentos.
def tokenize(texto):
    texto = ''.join([c for c in texto if c not in non_words])
    tokens = word_tokenize(texto)
    # stem
    try:
        stems = stem_tokens(tokens, stemmer)
    except Exception as e:
        print(e)
        print(texto)
        stems = ['']
    return stems

# Definición del vector de caracteristicas
count_vectorizer = CountVectorizer(
    analyzer='word',
    tokenizer=None,
    lowercase=True,
    stop_words=spanish_stopwords
)

# Crea el pipeline junto con el clasificador
text_clf = Pipeline([('vect', count_vectorizer),
                     ('tfidf', TfidfTransformer(use_idf=False)),
                     ('clf', BernoulliNB()),
                     ])

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

def evaluar_modelo():
    print('("******************* EVALUAR CORPUS *******************')    
    polaridad, texto = cargar_corpus('corpus/corpus_ok2.csv')
    # preparing data for split validation. 60% training, 40% test
    X_train, X_test, y_train, y_test = train_test_split(texto, polaridad, test_size=0.4, random_state=43)

    classifier = text_clf.fit(X_train,y_train)
    print("Score:",classifier.score(X_test,y_test))
    predicted = classifier.predict(X_test)
    print (classification_report(y_test,predicted))
    print ("Nivel de predicción {:.2%}".format(accuracy_score(y_test,predicted)))

# %%
evaluar_modelo()
# Out:
# ("******************* EVALUAR CORPUS *******************
# Score: 0.710084033613
#              precision    recall  f1-score   support
#
#    negativo       0.68      0.84      0.75       126
#    positivo       0.76      0.56      0.65       112
#
# avg / total       0.72      0.71      0.70       238
#
# Nivel de predicción 71.01%

# %%
# Preprocess crear term frequency matrix CountVectorizer convierte la columna de texto en una matriz 
# en la que cada palabra es una columna
# cuyo valor es el número de veces que dicha palabra aparece en cada texto. 
# Convierte a minusculas elimina signos de puntuacion y remueve stopwords
# Entrena el corpus y lo guarda como un objeto serializado.
def entrenar_clasificador():
    polaridad,texto = cargar_corpus('corpus/corpus_prog.csv')
    text_clf.fit(texto, polaridad)
    modelo = open("corpus/corpus_prog.m","wb")
    pickle.dump(text_clf, modelo)
    modelo.close()

# %%
# Dado un texto predice su sentimiento
def obtener_sentimiento(texto):
    modelo = open("corpus/corpus_prog.m", "rb")
    text_clf2 = pickle.load(modelo)
    modelo.close()

    newTexto = [(texto)]
    sentimiento = text_clf2.predict(newTexto)
    return(sentimiento)

# %%
def testing():
    print("**************************************** TRAINING CORPUS ******************************************")
    # Si es la primera vez se tiene que entrenar el corpus, después ya no es necesario
    entrenar_clasificador()
    print('me cansa estar viendo los mismos temaz = ',obtener_sentimiento('me cansa estar viendo los mismos temaz'))
    print('me desespera no poder entender al tema =', obtener_sentimiento('me desespera no poder entender al tema'))
    print('Programar en Java es divertido =', obtener_sentimiento('Programar en Java es divertido'))
    print('Me gusto el area en el que estoy, seguire trabajando en el proyecto =', obtener_sentimiento('Me gusto el area en el que estoy, seguire trabajando en el proyecto'))
    print("***********************************************************")

# %%
testing()
# Out:
# **************************************** TRAINING CORPUS ******************************************
# me cansa estar viendo los mismos temaz =  ['negativo']
# me desespera no poder entender al tema = ['negativo']
# Programar en Java es divertido = ['positivo']
# Me gusto el area en el que estoy, seguire trabajando en el proyecto = ['positivo']
# ***********************************************************
